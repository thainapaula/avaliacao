-- %% [markdown]
-- # [avaliacao-Cadastros]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [avaliacao-Cadastros]    Script Date: 07/03/2021 23:26:45 ******/
CREATE DATABASE [avaliacao-Cadastros]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'Cadastros', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL15.SQLEXPRESS\MSSQL\DATA\avaliacao-Cadastros.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'Cadastros_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL15.SQLEXPRESS\MSSQL\DATA\avaliacao-Cadastros_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT
GO
ALTER DATABASE [avaliacao-Cadastros] ADD FILEGROUP [SECONDARY]
GO
ALTER DATABASE [avaliacao-Cadastros] SET COMPATIBILITY_LEVEL = 140
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [avaliacao-Cadastros].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [avaliacao-Cadastros] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [avaliacao-Cadastros] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [avaliacao-Cadastros] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [avaliacao-Cadastros] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [avaliacao-Cadastros] SET ARITHABORT OFF 
GO
ALTER DATABASE [avaliacao-Cadastros] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [avaliacao-Cadastros] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [avaliacao-Cadastros] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [avaliacao-Cadastros] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [avaliacao-Cadastros] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [avaliacao-Cadastros] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [avaliacao-Cadastros] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [avaliacao-Cadastros] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [avaliacao-Cadastros] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [avaliacao-Cadastros] SET  DISABLE_BROKER 
GO
ALTER DATABASE [avaliacao-Cadastros] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [avaliacao-Cadastros] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [avaliacao-Cadastros] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [avaliacao-Cadastros] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [avaliacao-Cadastros] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [avaliacao-Cadastros] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [avaliacao-Cadastros] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [avaliacao-Cadastros] SET RECOVERY SIMPLE 
GO
ALTER DATABASE [avaliacao-Cadastros] SET  MULTI_USER 
GO
ALTER DATABASE [avaliacao-Cadastros] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [avaliacao-Cadastros] SET DB_CHAINING OFF 
GO
ALTER DATABASE [avaliacao-Cadastros] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [avaliacao-Cadastros] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [avaliacao-Cadastros] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [avaliacao-Cadastros] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
ALTER DATABASE [avaliacao-Cadastros] SET QUERY_STORE = OFF
GO

-- %% [markdown]
-- # [dbo].[Bairros]

-- %%
USE [avaliacao-Cadastros]
GO

-- %%
/****** Object:  Table [dbo].[Bairros]    Script Date: 07/03/2021 23:26:45 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Bairros](
	[BairroID] [int] NOT NULL,
	[CidadeID] [int] NOT NULL,
	[Nome] [nvarchar](100) NULL,
PRIMARY KEY NONCLUSTERED 
(
	[BairroID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, FILLFACTOR = 95, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [SECONDARY]
GO

-- %% [markdown]
-- # [dbo].[Cidades]

-- %%
/****** Object:  Table [dbo].[Cidades]    Script Date: 07/03/2021 23:26:45 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Cidades](
	[CidadeID] [int] NOT NULL,
	[Nome] [nvarchar](100) NULL,
PRIMARY KEY NONCLUSTERED 
(
	[CidadeID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, FILLFACTOR = 95, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [SECONDARY]
GO

-- %% [markdown]
-- # [dbo].[Clientes]

-- %%
/****** Object:  Table [dbo].[Clientes]    Script Date: 07/03/2021 23:26:45 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Clientes](
	[ClienteID] [int] NOT NULL,
	[Situacao] [nvarchar](40) NULL,
	[BairroID] [int] NOT NULL,
	[CidadeID] [int] NOT NULL,
	[UFID] [int] NOT NULL,
	[Nome] [nvarchar](100) NULL,
	[DataNascimento] [datetime] NULL,
	[Sexo] [nchar](1) NULL,
	[CPF] [nvarchar](40) NULL,
	[RG] [nvarchar](40) NULL,
	[Telefone] [nvarchar](40) NULL,
	[Celular] [nvarchar](40) NULL,
	[Endereco] [nvarchar](200) NULL,
	[CEP] [nvarchar](20) NULL,
	[DataCadastro] [datetime] NULL,
	[TipoCliente] [nvarchar](40) NULL,
PRIMARY KEY NONCLUSTERED 
(
	[ClienteID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, FILLFACTOR = 95, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [SECONDARY]
GO

-- %% [markdown]
-- # [dbo].[EmailsClientes]

-- %%
/****** Object:  Table [dbo].[EmailsClientes]    Script Date: 07/03/2021 23:26:45 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[EmailsClientes](
	[EmailClienteID] [int] IDENTITY(1,1) NOT NULL,
	[ClienteID] [int] NOT NULL,
	[Email] [nvarchar](400) NULL,
	[Padrao] [tinyint] NOT NULL,
 CONSTRAINT [EmailsClientes_PK] PRIMARY KEY NONCLUSTERED 
(
	[EmailClienteID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, FILLFACTOR = 95, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Estados]

-- %%
/****** Object:  Table [dbo].[Estados]    Script Date: 07/03/2021 23:26:45 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Estados](
	[UFID] [int] NOT NULL,
	[Estado] [nvarchar](2) NULL,
PRIMARY KEY NONCLUSTERED 
(
	[UFID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, FILLFACTOR = 95, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [SECONDARY]
GO

-- %% [markdown]
-- # [dbo].[PESSOAS]

-- %%
/****** Object:  Table [dbo].[PESSOAS]    Script Date: 07/03/2021 23:26:45 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[PESSOAS](
	[NUMERO_U] [nvarchar](50) NOT NULL,
	[SIT] [nvarchar](50) NULL,
	[NOME] [nvarchar](50) NULL,
	[CPF] [nvarchar](50) NULL,
	[RG] [nvarchar](50) NULL,
	[FONE1] [nvarchar](50) NULL,
	[BAIRRO] [nvarchar](50) NULL,
	[CIDADE] [nvarchar](50) NULL,
	[FONE2] [nvarchar](50) NULL,
	[EMAIL] [nvarchar](100) NULL,
	[CEP] [nvarchar](50) NULL,
	[LOGRADOURO] [nvarchar](50) NULL,
	[NUMERO] [int] NULL,
	[TIPO_P] [nvarchar](50) NULL,
	[DATA_NASC] [datetime2](7) NULL,
	[DATA_CAD] [nvarchar](50) NULL,
	[SEXO] [nvarchar](50) NULL,
	[ESTADO] [nvarchar](50) NOT NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[SITP]

-- %%
/****** Object:  Table [dbo].[SITP]    Script Date: 07/03/2021 23:26:45 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[SITP](
	[SITPCD] [nvarchar](50) NOT NULL,
	[DESC] [nvarchar](50) NOT NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TPP]

-- %%
/****** Object:  Table [dbo].[TPP]    Script Date: 07/03/2021 23:26:45 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TPP](
	[TPPCD] [nvarchar](50) NOT NULL,
	[DESC] [nvarchar](50) NOT NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [DF__Bairros__BairroI__44FF419A]

-- %%
ALTER TABLE [dbo].[Bairros] ADD  DEFAULT ((0)) FOR [BairroID]
GO

-- %% [markdown]
-- # [DF__Bairros__CidadeI__45F365D3]

-- %%
ALTER TABLE [dbo].[Bairros] ADD  DEFAULT ((0)) FOR [CidadeID]
GO

-- %% [markdown]
-- # [DF__Bairros__Nome__46E78A0C]

-- %%
ALTER TABLE [dbo].[Bairros] ADD  DEFAULT ('') FOR [Nome]
GO

-- %% [markdown]
-- # [DF__Cidades__CidadeI__412EB0B6]

-- %%
ALTER TABLE [dbo].[Cidades] ADD  DEFAULT ((0)) FOR [CidadeID]
GO

-- %% [markdown]
-- # [DF__Cidades__Nome__4222D4EF]

-- %%
ALTER TABLE [dbo].[Cidades] ADD  DEFAULT ('') FOR [Nome]
GO

-- %% [markdown]
-- # [DF__Clientes__Client__4AB81AF0]

-- %%
ALTER TABLE [dbo].[Clientes] ADD  DEFAULT ((0)) FOR [ClienteID]
GO

-- %% [markdown]
-- # [DF__Clientes__Situac__4BAC3F29]

-- %%
ALTER TABLE [dbo].[Clientes] ADD  DEFAULT ('') FOR [Situacao]
GO

-- %% [markdown]
-- # [DF__Clientes__Bairro__4CA06362]

-- %%
ALTER TABLE [dbo].[Clientes] ADD  DEFAULT ((0)) FOR [BairroID]
GO

-- %% [markdown]
-- # [DF__Clientes__Cidade__4D94879B]

-- %%
ALTER TABLE [dbo].[Clientes] ADD  DEFAULT ((0)) FOR [CidadeID]
GO

-- %% [markdown]
-- # [DF__Clientes__UFID__4E88ABD4]

-- %%
ALTER TABLE [dbo].[Clientes] ADD  DEFAULT ((0)) FOR [UFID]
GO

-- %% [markdown]
-- # [DF__Clientes__Nome__4F7CD00D]

-- %%
ALTER TABLE [dbo].[Clientes] ADD  DEFAULT ('') FOR [Nome]
GO

-- %% [markdown]
-- # [DF__Clientes__Sexo__5070F446]

-- %%
ALTER TABLE [dbo].[Clientes] ADD  DEFAULT ('') FOR [Sexo]
GO

-- %% [markdown]
-- # [DF__Clientes__CPF__5165187F]

-- %%
ALTER TABLE [dbo].[Clientes] ADD  DEFAULT ('') FOR [CPF]
GO

-- %% [markdown]
-- # [DF__Clientes__RG__52593CB8]

-- %%
ALTER TABLE [dbo].[Clientes] ADD  DEFAULT ('') FOR [RG]
GO

-- %% [markdown]
-- # [DF__Clientes__Telefo__534D60F1]

-- %%
ALTER TABLE [dbo].[Clientes] ADD  DEFAULT ('') FOR [Telefone]
GO

-- %% [markdown]
-- # [DF__Clientes__Celula__5441852A]

-- %%
ALTER TABLE [dbo].[Clientes] ADD  DEFAULT ('') FOR [Celular]
GO

-- %% [markdown]
-- # [DF__Clientes__Endere__5535A963]

-- %%
ALTER TABLE [dbo].[Clientes] ADD  DEFAULT ('') FOR [Endereco]
GO

-- %% [markdown]
-- # [DF__Clientes__CEP__5629CD9C]

-- %%
ALTER TABLE [dbo].[Clientes] ADD  DEFAULT ('') FOR [CEP]
GO

-- %% [markdown]
-- # [DF__Clientes__TipoCl__571DF1D5]

-- %%
ALTER TABLE [dbo].[Clientes] ADD  DEFAULT ('') FOR [TipoCliente]
GO

-- %% [markdown]
-- # [DF__EmailsCli__Clien__5CD6CB2B]

-- %%
ALTER TABLE [dbo].[EmailsClientes] ADD  DEFAULT ((0)) FOR [ClienteID]
GO

-- %% [markdown]
-- # [DF__EmailsCli__Email__5DCAEF64]

-- %%
ALTER TABLE [dbo].[EmailsClientes] ADD  DEFAULT ('') FOR [Email]
GO

-- %% [markdown]
-- # [DF__EmailsCli__Padra__5EBF139D]

-- %%
ALTER TABLE [dbo].[EmailsClientes] ADD  DEFAULT ((0)) FOR [Padrao]
GO

-- %% [markdown]
-- # [DF__Estados__UFID__3D5E1FD2]

-- %%
ALTER TABLE [dbo].[Estados] ADD  DEFAULT ((0)) FOR [UFID]
GO

-- %% [markdown]
-- # [DF__Estados__Estado__3E52440B]

-- %%
ALTER TABLE [dbo].[Estados] ADD  DEFAULT ('') FOR [Estado]
GO

-- %% [markdown]
-- # [FK__Bairros__CidadeI__47DBAE45]

-- %%
ALTER TABLE [dbo].[Bairros]  WITH NOCHECK ADD FOREIGN KEY([CidadeID])
REFERENCES [dbo].[Cidades] ([CidadeID])
GO

-- %% [markdown]
-- # [FK__Clientes__Bairro__5812160E]

-- %%
ALTER TABLE [dbo].[Clientes]  WITH NOCHECK ADD FOREIGN KEY([BairroID])
REFERENCES [dbo].[Bairros] ([BairroID])
GO

-- %% [markdown]
-- # [FK__Clientes__Cidade__59063A47]

-- %%
ALTER TABLE [dbo].[Clientes]  WITH NOCHECK ADD FOREIGN KEY([CidadeID])
REFERENCES [dbo].[Cidades] ([CidadeID])
GO

-- %% [markdown]
-- # [FK__Clientes__UFID__59FA5E80]

-- %%
ALTER TABLE [dbo].[Clientes]  WITH NOCHECK ADD FOREIGN KEY([UFID])
REFERENCES [dbo].[Estados] ([UFID])
GO

-- %% [markdown]
-- # [EmailsClientes_ClienteID]

-- %%
ALTER TABLE [dbo].[EmailsClientes]  WITH NOCHECK ADD  CONSTRAINT [EmailsClientes_ClienteID] FOREIGN KEY([ClienteID])
REFERENCES [dbo].[Clientes] ([ClienteID])
GO
ALTER TABLE [dbo].[EmailsClientes] NOCHECK CONSTRAINT [EmailsClientes_ClienteID]
GO

-- %% [markdown]
-- # [avaliacao-Cadastros]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [avaliacao-Cadastros] SET  READ_WRITE 
GO
